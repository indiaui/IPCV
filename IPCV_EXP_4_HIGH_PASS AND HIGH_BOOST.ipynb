# %% [markdown]
# **HIGH PASS FILTER & HIGH BOOST FILTER**

# %%
#Installing opencv library
# !pip install opencv-python

# %%
import cv2
import numpy as np

# %%
#Reading an Image
import cv2
img = cv2.imread(r"/content/cameramen.png",0)

# %%
#Display an Image - using Google Colab
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
# Obtain number of rows and columns
row,col = img.shape

# %%
print("Rows of image is : ",row)
print("Columns of image is : ",col)
# Out:
# Rows of image is :  256
# Columns of image is :  256

# %%
#HIGH PASS mask
mask = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
print("High Pass mask is : \n",mask)
# Out:
# High Pass mask is :
#  [[-1 -1 -1]
#  [-1  8 -1]
#  [-1 -1 -1]]

# %%
  # Convolve the 3X3 mask over the image -> High Pass Mask
  filtered_image = np.zeros([row, col])

  for i in range(1,row-1):
    for j in range(1,col-1):
      temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
      filtered_image[i, j]= temp

  print("Original image is : ")
  cv2_imshow(img)
  print("High Pass Filtered image is : ")
  cv2_imshow(filtered_image)
# Out:
# Original image is :
# <PIL.Image.Image image mode=L size=256x256>
# High Pass Filtered image is :
# <PIL.Image.Image image mode=L size=256x256>

# %%
#HIGH PASS mask
mask = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
mask = mask/9
print("High Pass mask is : \n",mask)
# Out:
# High Pass mask is :
#  [[-0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111  0.88888889 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111]]

# %%
# Convolve the 3X3 mask over the image -> High Pass Mask
filtered_image = np.zeros([row, col])

for i in range(1,row-1):
  for j in range(1,col-1):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    filtered_image[i, j]= temp

print("Original image is : ")
cv2_imshow(img)
print("High Pass Filtered image is : ")
cv2_imshow(filtered_image)
# Out:
# Original image is :
# <PIL.Image.Image image mode=L size=256x256>
# High Pass Filtered image is :
# <PIL.Image.Image image mode=L size=256x256>

# %%
#HIGH Boost mask
mask = np.array([[-1,-1,-1],[-1,8.9,-1],[-1,-1,-1]])
mask = mask/9
print("High Boost mask is : \n",mask)
# Out:
# High Boost mask is :
#  [[-0.11111111 -0.11111111 -0.11111111]
#  [-0.11111111  0.98888889 -0.11111111]
#  [-0.11111111 -0.11111111 -0.11111111]]

# %%
# Convolve the 3X3 mask over the image -> High Boost Mask
filtered_image = np.zeros([row, col])

for i in range(1,row-1):
  for j in range(1,col-1):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    filtered_image[i, j]= temp

print("Original image is : ")
cv2_imshow(img)
print("High Boost Filtered image is : ")
cv2_imshow(filtered_image)
# Out:
# Original image is :
# <PIL.Image.Image image mode=L size=256x256>
# High Boost Filtered image is :
# <PIL.Image.Image image mode=L size=256x256>

# %%
#HIGH Boost mask
mask = np.array([[-1,-1,-1],[-1,8.9,-1],[-1,-1,-1]])
print("High Boost mask is : \n",mask)
# Out:
# High Boost mask is :
#  [[-1.  -1.  -1. ]
#  [-1.   8.9 -1. ]
#  [-1.  -1.  -1. ]]

# %%
# Convolve the 3X3 mask over the image -> High Boost Mask
filtered_image = np.zeros([row, col])

for i in range(1,row-1):
  for j in range(1,col-1):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    filtered_image[i, j]= temp

print("Original image is : ")
cv2_imshow(img)
print("High Boost Filtered image is : ")
cv2_imshow(filtered_image)
# Out:
# Original image is :
# <PIL.Image.Image image mode=L size=256x256>
# High Boost Filtered image is :
# <PIL.Image.Image image mode=L size=256x256>
